# %%
import json
import pandas as pd
import os

# %%
# %matplotlib inline

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'pair_programming_data_parsing.ipynb',
#  'pair_programming_data_parsing_solution.ipynb',
#  'sugar_usage_america.ipynb',
#  'sugar_usage_table50.csv']

# %%
df = pd.read_csv('sugar_usage_table50.csv')
df.head()
df.describe()
# Out:
#        Calendar year  U.S. population 3/  Refined sugar 4/       HFCS  \
# count       50.00000           50.000000          50.00000  50.000000
# mean      1990.50000          255.898000          74.43800  36.902000
# std         14.57738           38.573452          14.89669  22.987463
# min       1966.00000          196.600000          60.00000   0.000000
# 25%       1978.25000          222.725000          63.67500  11.800000
# 50%       1990.50000          251.300000          65.95000  46.250000
# 75%       2002.75000          289.675000          89.27500  56.125000
# max       2015.00000          321.400000         102.30000  63.800000
#
#        Corn-Glucose syrup  Corn-Dextrose  Corn-Total  Pure honey  \
# count            50.00000      50.000000   50.000000   50.000000
# mean             13.63000       3.612000   54.146000    0.958000
# std               1.83495       0.551303   23.949643    0.124687
# min               9.70000       2.600000   13.900000    0.700000
# ...

# %%
df.plot.box(y=['HFCS','Corn-Glucose syrup','Corn-Dextrose','Refined sugar 4/'])

# %%
df.plot(x='Calendar year', y='Total caloric sweeteners')

# %%
df.plot.line(x = 'Calendar year', y = ['HFCS','Refined sugar 4/','Corn-Total','Pure honey','Edible syrups'])
df.plot.line(x = 'Calendar year', y = ['Pure honey','Edible syrups'])
df.plot.line(x = 'Calendar year', y = ['Total caloric sweeteners'])

# %%
df.plot(x='Calendar year', y='Refined sugar 4/')
